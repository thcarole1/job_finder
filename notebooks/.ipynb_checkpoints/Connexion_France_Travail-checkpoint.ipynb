# %% [markdown]
# # Connexion à l'API France Travail

# %% [markdown]
# URL :
#
# https://francetravail.io/data/api/offres-emploi
#
# https://francetravail.io/data/api/offres-emploi/documentation#/

# %% [markdown]
# ## Imports

# %%
import http.client
import requests
import json
import pandas as pd
import os

# %%
# ---------------------------
# CONFIGURATION
# ---------------------------
# France Travail (ex-Pôle emploi)
# FT_CLIENT_ID = Defined in .env
# FT_CLIENT_SECRET = Defined in .env
# FT_SCOPE = Defined in .env

##################  VARIABLES  ##################
FT_CLIENT_ID = os.environ.get("FT_CLIENT_ID")
FT_CLIENT_SECRET = os.environ.get("FT_CLIENT_SECRET")
FT_SCOPE = os.environ.get("FT_SCOPE")

# Paramètres de recherche
JOB_QUERY = "data scientist"
COMMUNE = "78300"
DISTANCE = 500
BLOC_PAGINATION = 50

MAX_PAGES = 1   # Limiter le nombre de pages récupérées

# ---------------------------
# AUTH FRANCE TRAVAIL
# ---------------------------
def get_ft_token():
    url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
    data = {
        "grant_type": "client_credentials",
        "client_id": FT_CLIENT_ID,
        "client_secret": FT_CLIENT_SECRET,
        "scope": FT_SCOPE,
    }
    r = requests.post(url, data=data)
    r.raise_for_status()
    return r.json()["access_token"]

# ---------------------------
# API CALL FRANCE TRAVAIL
# ---------------------------
def fetch_france_travail_jobs(token, max_pages=MAX_PAGES):
    headers = {"Authorization": f"Bearer {token}"}
    all_jobs = []
    b_stop_criteria = False
    
    for page in range(1, max_pages + 1):
        if b_stop_criteria == False:    
            url = f"https://api.francetravail.io/partenaire/offresdemploi/v2/offres/search"
            params = {
                "motsCles": JOB_QUERY,
                "commune": COMMUNE,
                "distance" : DISTANCE,
                "range": f"{(page-1)*BLOC_PAGINATION}-{page*BLOC_PAGINATION-1}"  # pagination par blocs de 50
            }
            r = requests.get(url, headers=headers, params=params)
            r.raise_for_status()
            data = r.json()
            offres = data.get("resultats", [])
                
            for o in offres:
                all_jobs.append({
                    "source": "France Travail",
                    "id":o.get("id"),                    
                    "titre": o.get("intitule"),
                    "description": o.get("description"),
                    "date": o.get("dateCreation"),
                    "date_actualisation": o.get("dateActualisation"),
                    "lieu_libelle": o.get("lieuTravail", {}).get("libelle"),
                    "lieu_latitude": o.get("lieuTravail", {}).get("latitude"),
                    "lieu_longitude": o.get("lieuTravail", {}).get("longitude"),
                    "lieu_codePostal": o.get("lieuTravail", {}).get("codePostal"),
                    "lieu_commune": o.get("lieuTravail", {}).get("commune"),
                    "entreprise_nom": o.get("entreprise", {}).get("nom"),
                    "entreprise_description": o.get("entreprise", {}).get("description"),
                    "entreprise_logo": o.get("entreprise", {}).get("logo"),
                    "entreprise_url": o.get("entreprise", {}).get("url"),
                    "typeContrat": o.get("typeContrat"),
                    "typeContratLibelle": o.get("typeContratLibelle"),
                    "natureContrat": o.get("natureContrat"),
                    "experienceExige": o.get("experienceExige"),
                    "experienceLibelle": o.get("experienceLibelle"),
                    "experienceCommentaire": o.get("experienceCommentaire"),
                    "experienceCommentaire": o.get("experienceCommentaire"),      
                    "formations": o.get("formations"),
                    "formations_codeFormation": o.get("formations")[0].get("codeFormation") if o.get("formations") is not None else "None",
                    "formations_domaineLibelle": o.get("formations")[0].get("domaineLibelle") if o.get("formations") is not None else "None",
                    "formations_niveauLibelle": o.get("formations")[0].get("niveauLibelle") if o.get("formations") is not None else "None",
                    "formations_commentaire": o.get("formations")[0].get("commentaire") if o.get("formations") is not None else "None",
                    "formations_exigence": o.get("formations")[0].get("exigence") if o.get("formations") is not None else "None",
                    "langues": o.get("langues"),
                    "langues_libelle": o.get("langues")[0].get("libelle") if o.get("langues") is not None else "None",
                    "langues_exigence": o.get("langues")[0].get("exigence") if o.get("langues") is not None else "None",
                
                    "permis": o.get("permis"),
                    "permis_libelle": o.get("permis")[0].get("libelle") if o.get("permis") is not None else "None",
                    "permis_exigence": o.get("permis")[0].get("exigence") if o.get("permis") is not None else "None",

                    "outilsBureautiques": o.get("outilsBureautiques"),

                    "competences": o.get("competences"),
                    "permis_code": o.get("competences")[0].get("code") if o.get("competences") is not None else "None",
                    "permis_libelle": o.get("competences")[0].get("libelle") if o.get("competences") is not None else "None",
                    "permis_exigence": o.get("competences")[0].get("exigence") if o.get("competences") is not None else "None",

                    "salaire": o.get("salaire"),
                    "salaire_libelle": o.get("salaire").get("libelle") if o.get("salaire") is not None else "None",
                    "salaire_commentaire": o.get("salaire").get("commentaire") if o.get("salaire") is not None else "None",
                    "salaire_complement1": o.get("salaire").get("complement1") if o.get("salaire") is not None else "None",
                    "salaire_complement2": o.get("salaire").get("complement2") if o.get("salaire") is not None else "None",

                    "dureeTravailLibelle": o.get("dureeTravailLibelle"),

                    "dureeTravailLibelleConverti": o.get("dureeTravailLibelleConverti"),
                    "complementExercice": o.get("complementExercice"),
                    "conditionExercice": o.get("conditionExercice"),
                    "alternance": o.get("alternance"),

                    "contact": o.get("contact"),
                    "contact_nom": o.get("contact").get("nom") if o.get("contact") is not None else "None",
                    "contact_coordonnees1": o.get("contact").get("coordonnees1") if o.get("contact") is not None else "None",
                    "contact_coordonnees2": o.get("contact").get("coordonnees2") if o.get("contact") is not None else "None",
                    "contact_coordonnees3": o.get("contact").get("coordonnees3") if o.get("contact") is not None else "None",
                    "contact_telephone": o.get("contact").get("telephone") if o.get("contact") is not None else "None",
                    "contact_courriel": o.get("contact").get("courriel") if o.get("contact") is not None else "None",
                    "contact_commentaire": o.get("contact").get("commentaire") if o.get("contact") is not None else "None",
                    "contact_urlRecruteur": o.get("contact").get("urlRecruteur") if o.get("contact") is not None else "None",
                    "contact_urlPostulation": o.get("contact").get("urlPostulation") if o.get("contact") is not None else "None",

                    "agence": o.get("agence"),
                    "agence_telephone": o.get("agence").get("telephone") if o.get("agence") is not None else "None",
                    "agence_courriel": o.get("agence").get("courriel") if o.get("agence") is not None else "None",

                    "nombrePostes": o.get("nombrePostes"),
                    "deplacementCode": o.get("deplacementCode"),
                    "deplacementLibelle": o.get("deplacementLibelle"),

                    "qualificationCode": o.get("qualificationCode"),
                    "qualificationLibelle": o.get("qualificationLibelle"),

                    "codeNAF": o.get("codeNAF"),
                    "secteurActivite": o.get("secteurActivite"),
                    "secteurActiviteLibelle": o.get("secteurActiviteLibelle"),
                    
                    "qualitesProfessionnelles": o.get("qualitesProfessionnelles"),
                    "qualitesProfessionnelles_libelle": o.get("qualitesProfessionnelles")[0].get("libelle") if o.get("qualitesProfessionnelles") is not None else "None",
                    "qualitesProfessionnelles_description": o.get("qualitesProfessionnelles")[0].get("description") if o.get("qualitesProfessionnelles") is not None else "None",

                    "trancheEffectifEtab": o.get("trancheEffectifEtab"),


                    "origineOffre": o.get("origineOffre"),
                    "origineOffre_origine": o.get("origineOffre").get("origine") if o.get("origineOffre") is not None else "None",
                    "origineOffre_urlOrigine": o.get("origineOffre").get("urlOrigine") if o.get("origineOffre") is not None else "None",
                    "origineOffre_partenaires": o.get("origineOffre").get("partenaires") if o.get("origineOffre") is not None else "None",

                    "origineOffre_partenaires_nom": o.get("origineOffre").get("partenaires")[0].get("nom") if o.get("origineOffre").get("partenaires") is not None else "None",
                    "origineOffre_partenaires_url": o.get("origineOffre").get("partenaires")[0].get("url") if o.get("origineOffre").get("partenaires") is not None else "None",
                    "origineOffre_partenaires_logo": o.get("origineOffre").get("partenaires")[0].get("logo") if o.get("origineOffre").get("partenaires") is not None else "None",

                    "offresManqueCandidats": o.get("offresManqueCandidats"),

                    "contexteTravail": o.get("contexteTravail"),
                    "contexteTravail_horaires": o.get("contexteTravail").get("horaires") if o.get("contexteTravail") is not None else "None",
                    "contexteTravail_conditionsExercice": o.get("contexteTravail").get("conditionsExercice") if o.get("contexteTravail") is not None else "None",
                    
                    "lieu": o.get("lieuTravail", {}).get("libelle"),                    
                    "url": o.get("origineOffre", {}).get("urlOrigine")
                })
            print(len(offres))
            
            if len(offres) < BLOC_PAGINATION:
                b_stop_criteria = True
            
    return all_jobs

# ---------------------------
# MAIN
# ---------------------------
if __name__ == "__main__":
    print("Authentification France Travail...")
    token = get_ft_token()

    print("Récupération des offres France Travail...")
    ft_jobs = fetch_france_travail_jobs(token)

    print("Affichage Extract offres France Travail...")
    df = pd.DataFrame(ft_jobs)
    display(df.head(20))

    # Export vers CSV
    df.to_csv("../data/raw_data/offres_emploi.csv", index=False, encoding="utf-8")
    print(f"{len(ft_jobs)} offres uniques exportées dans offres_emploi.csv ✅")
# Out:
# Authentification France Travail...
# Récupération des offres France Travail...
# 50
# Affichage Extract offres France Travail...
#             source       id  \
# 0   France Travail  197TJGR
# 1   France Travail  197QNVL
# 2   France Travail  197PFLJ
# 3   France Travail  197PFBS
# 4   France Travail  197JFPL
# 5   France Travail  197HRZP
# 6   France Travail  197HZVD
# 7   France Travail  197HDVX
# 8   France Travail  196RLRG
# 9   France Travail  197JQWD
# 10  France Travail  195XMNP
# 11  France Travail  197RYBN
# 12  France Travail  197HFZB
# 13  France Travail  2369155
# 14  France Travail  2310091
# 15  France Travail  2289750
# 16  France Travail  2305881
# 17  France Travail  2360172
# 18  France Travail  2340064
# 19  France Travail  2254845
#
#                                                 titre  \
# 0                    Data Scientist - H/F - CDI (H/F)
# 1                         Senior Data Scientist (H/F)
# 2                       Data Scientist - Senior (H/F)
# 3                           Lead Data Scientist (H/F)
# 4                                Data scientist (H/F)
# 5                                Data scientist (H/F)
# 6                                Data scientist (H/F)
# 7   Ingénieur-e  de recherche data-scientist h/f (...
# 8       Ingénieur-e de recherche data-scientist (H/F)
# 9                               Chargé d'études (H/F)
# 10                                    Lead data (H/F)
# 11  Chargé de mission reprise données Dossier Usag...
# 12                     Data Scientist Junior HF (H/F)
# 13                           Data scientist f/h (H/F)
# 14                               Data Scientist (H/F)
# 15                               Data Scientist (H/F)
# 16                 Consultant(e) Data Scientist (H/F)
# 17             Lead Data Scientist / IA (H/F) - Reims
# 18                     Lead Data Scientist / IA (H/F)
# 19     Data Scientist - AI & Data Visualisation (H/F)
#
#                                           description  \
# 0   Intégré(e) au sein de l'équipe Data, vous part...
# 1   Descriptif du poste\n\nAu sein de l'équipe Dat...
# 2   Nous recrutons un(e) Data Scientist Senior pou...
# 3   Nous recrutons un(e) Lead Data Scientist pour ...
# 4    Missions au sein de la F2RSM Psy :\nSous la r...
# 5   Allianz France, depuis 2016, développe des cap...
# 6   Ingénieur(e) en IA pour différentes missions, ...
# 7   Pourquoi a-t-on besoin de vous?\nAu sein de la...
# 8   Pourquoi a-t-on besoin de vous ?\n\nAu sein de...
# 9   Avec près de 1 100 salariés et environ 2 milli...
# 10  Qui sommes-nous ?\n\nNous sommes passionnés pa...
# 11  L'association Les PEP CBFC a engagé la mise en...
# 12  Missions principales : \n\nAu sein du service ...
# 13  Safran est un groupe international de haute te...
# 14  En tant qu&#039;organisateur de forums de recr...
# 15  RESPONSABILITÉS : \n\nLa plateforme Data Scien...
# 16  À propos de nous : \nLayerScale Advisory, soci...
# 17  Directement intégré a une petite équipe et en ...
# 18  Directement intégré a une petite équipe et en ...
# 19  Dassault Systèmes, l'entreprise de la 3DEXPERI...
#
#                         date        date_actualisation  \
# 0   2025-09-12T15:47:35.716Z  2025-09-12T15:47:36.257Z
# 1   2025-09-10T14:39:46.067Z  2025-09-10T14:39:46.609Z
# 2   2025-09-09T14:55:00.882Z  2025-09-09T14:55:01.363Z
# 3   2025-09-09T14:51:41.441Z  2025-09-09T14:51:41.883Z
# 4   2025-09-04T09:08:08.298Z  2025-09-04T13:48:05.572Z
# 5   2025-09-03T14:57:02.718Z  2025-09-04T10:58:13.036Z
# 6   2025-09-03T17:53:28.629Z  2025-09-12T07:54:12.616Z
# 7   2025-09-03T10:44:09.081Z  2025-09-03T13:50:37.013Z
# 8   2025-08-20T11:35:00.575Z  2025-09-01T13:59:51.923Z
# 9   2025-09-04T12:17:03.096Z  2025-09-04T13:13:22.606Z
# 10  2025-07-30T09:49:43.957Z  2025-09-01T13:29:18.704Z
# 11  2025-09-11T15:00:30.922Z  2025-09-12T08:48:17.085Z
# 12  2025-09-03T10:59:15.634Z  2025-09-04T08:51:31.638Z
# 13  2025-09-14T04:32:42.000Z  2025-09-14T04:32:42.000Z
# 14  2025-09-13T08:40:36.000Z  2025-09-14T09:27:19.000Z
# 15  2025-09-13T02:31:19.000Z                      None
# 16  2025-09-13T07:45:25.000Z  2025-09-13T07:45:25.000Z
# 17  2025-09-13T20:38:22.000Z  2025-09-14T07:00:24.000Z
# 18  2025-09-13T14:42:02.000Z                      None
# 19  2025-09-12T11:47:17.000Z  2025-09-12T11:47:17.000Z
#
#                      lieu_libelle  lieu_latitude  lieu_longitude  \
# 0                   75 - PARIS 09      48.872479        2.341194
# 1                   75 - PARIS 02            NaN             NaN
# 2                   75 - PARIS 09      48.872479        2.341194
# 3                   75 - PARIS 09      48.872479        2.341194
# 4         59 - ST ANDRE LEZ LILLE      50.661022        3.050033
# 5                    92 - PUTEAUX      48.884019        2.237979
# 6                   75 - PARIS 01            NaN             NaN
# 7              93 - Aubervilliers      48.914557        2.381792
# 8              93 - AUBERVILLIERS      48.914557        2.381792
# 9                   75 - PARIS 15      48.841401        2.300274
# 10              69 - VILLEURBANNE      45.766536        4.879601
# 11                     21 - DIJON      47.350710        5.051957
# 12                   38 - CROLLES      45.284855        5.883035
# 13                     87 - Nexon      45.683300        1.183330
# 14                  92 - Nanterre      48.879998        2.207752
# 15  75 - Paris 14e Arrondissement      48.832769        2.325738
# 16                     75 - Paris            NaN             NaN
# 17                     51 - Reims      49.213062        4.026372
# 18                     51 - Reims      49.213062        4.026372
# 19       78 - Vélizy-Villacoublay      48.797269        2.194266
#
#    lieu_codePostal  ...                           origineOffre_partenaires  \
# 0            75009  ...                                               None
# 1            75002  ...                                               None
# 2            75009  ...                                               None
# 3            75009  ...                                               None
# 4            59350  ...                                               None
# 5            92800  ...                                               None
# 6            75001  ...                                               None
# 7            93300  ...                                               None
# 8            93300  ...                                               None
# 9            75015  ...                                               None
# 10           69100  ...                                               None
# 11           21000  ...                                               None
# 12           38920  ...                                               None
# 13           87800  ...  [{'nom': 'AEROCONTACT', 'url': 'https://www.ae...
# 14           92000  ...  [{'nom': 'HANDICAP_JOB', 'url': 'https://www.h...
# 15           75014  ...  [{'nom': 'BEETWEEN', 'url': 'https://app.beetw...
# 16            None  ...  [{'nom': 'INDEED', 'url': 'https://fr.indeed.c...
# 17           51100  ...  [{'nom': 'DIRECTEMPLOI', 'url': 'https://www.d...
# 18           51100  ...  [{'nom': 'TALENTPLUG', 'url': 'http://app.myta...
# 19           78140  ...  [{'nom': 'HANDICAP_JOB', 'url': 'https://www.h...
#
#    origineOffre_partenaires_nom  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# 5                          None
# 6                          None
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12                         None
# 13                  AEROCONTACT
# 14                 HANDICAP_JOB
# 15                     BEETWEEN
# 16                       INDEED
# 17                 DIRECTEMPLOI
# 18                   TALENTPLUG
# 19                 HANDICAP_JOB
#
#                          origineOffre_partenaires_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  https://www.aerocontact.com/emploi-aeronautiqu...
# 14  https://www.handicap-job.com/recherche/detail/...
# 15  https://app.beetween.com/WeaselWeb/p/#/apply/j...
# 16  https://fr.indeed.com/job/consultante-data-sci...
# 17  https://www.directemploi.com/candidatOffre/525...
# 18  http://app.mytalentplug.com/description-offre....
# 19  https://www.handicap-job.com/recherche/detail/...
#
#                         origineOffre_partenaires_logo offresManqueCandidats  \
# 0                                                None                 False
# 1                                                None                 False
# 2                                                None                 False
# 3                                                None                 False
# 4                                                None                 False
# 5                                                None                 False
# 6                                                None                 False
# 7                                                None                 False
# 8                                                None                 False
# 9                                                None                 False
# 10                                               None                  True
# 11                                               None                 False
# 12                                               None                 False
# 13  https://www.francetravail.fr/logos/img/partena...                  None
# 14  https://www.francetravail.fr/logos/img/partena...                  None
# 15  https://www.francetravail.fr/logos/img/partena...                  None
# 16  https://www.francetravail.fr/logos/img/partena...                  None
# 17  https://www.francetravail.fr/logos/img/partena...                  None
# 18  https://www.francetravail.fr/logos/img/partena...                  None
# 19  https://www.francetravail.fr/logos/img/partena...                  None
#
#                                       contexteTravail  \
# 0    {'horaires': ['39H/semaine
# Travail en journée']}
# 1   {'horaires': ['35H/semaine
# Travail en journée'...
# 2    {'horaires': ['35H/semaine
# Travail en journée']}
# 3    {'horaires': ['35H/semaine
# Travail en journée']}
# 4   {'horaires': ['37H30/semaine
# Travail en journé...
# 5   {'horaires': ['36H/semaine
# Travail en journée'...
# 6   {'horaires': ['Temps partiel - 7H/semaine
# Trav...
# 7    {'horaires': ['35H/semaine
# Travail en journée']}
# 8   {'horaires': ['37H30/semaine
# Travail en journé...
# 9    {'horaires': ['39H/semaine
# Travail en journée']}
# 10   {'horaires': ['35H/semaine
# Travail en journée']}
# 11   {'horaires': ['35H/semaine
# Travail en journée']}
# 12   {'horaires': ['35H/semaine
# Travail en journée']}
# 13                      {'horaires': ['00H/semaine']}
# 14                      {'horaires': ['00H/semaine']}
# 15   {'horaires': ['38H/semaine
# Travail en journée']}
# 16                      {'horaires': ['00H/semaine']}
# 17                      {'horaires': ['00H/semaine']}
# 18   {'horaires': ['00H/semaine
# Travail en journée']}
# 19                      {'horaires': ['00H/semaine']}
#
#                              contexteTravail_horaires  \
# 0                   [39H/semaine\nTravail en journée]
# 1                   [35H/semaine\nTravail en journée]
# 2                   [35H/semaine\nTravail en journée]
# 3                   [35H/semaine\nTravail en journée]
# 4                 [37H30/semaine\nTravail en journée]
# 5   [36H/semaine\nTravail en journée,  Horaires an...
# 6    [Temps partiel - 7H/semaine\nTravail en journée]
# 7                   [35H/semaine\nTravail en journée]
# 8                 [37H30/semaine\nTravail en journée]
# 9                   [39H/semaine\nTravail en journée]
# 10                  [35H/semaine\nTravail en journée]
# 11                  [35H/semaine\nTravail en journée]
# 12                  [35H/semaine\nTravail en journée]
# 13                                      [00H/semaine]
# 14                                      [00H/semaine]
# 15                  [38H/semaine\nTravail en journée]
# 16                                      [00H/semaine]
# 17                                      [00H/semaine]
# 18                  [00H/semaine\nTravail en journée]
# 19                                      [00H/semaine]
#
#    contexteTravail_conditionsExercice                           lieu  \
# 0                                None                  75 - PARIS 09
# 1                             [Autre]                  75 - PARIS 02
# 2                                None                  75 - PARIS 09
# 3                                None                  75 - PARIS 09
# 4                                None        59 - ST ANDRE LEZ LILLE
# 5                                None                   92 - PUTEAUX
# 6                                None                  75 - PARIS 01
# 7                                None             93 - Aubervilliers
# 8                                None             93 - AUBERVILLIERS
# 9                                None                  75 - PARIS 15
# 10                               None              69 - VILLEURBANNE
# 11                               None                     21 - DIJON
# 12                               None                   38 - CROLLES
# 13                               None                     87 - Nexon
# 14                               None                  92 - Nanterre
# 15                               None  75 - Paris 14e Arrondissement
# 16                               None                     75 - Paris
# 17                               None                     51 - Reims
# 18                               None                     51 - Reims
# 19                               None       78 - Vélizy-Villacoublay
#
#                                                   url
# 0   https://candidat.francetravail.fr/offres/reche...
# 1   https://candidat.francetravail.fr/offres/reche...
# 2   https://candidat.francetravail.fr/offres/reche...
# 3   https://candidat.francetravail.fr/offres/reche...
# 4   https://candidat.francetravail.fr/offres/reche...
# 5   https://candidat.francetravail.fr/offres/reche...
# 6   https://candidat.francetravail.fr/offres/reche...
# 7   https://candidat.francetravail.fr/offres/reche...
# 8   https://candidat.francetravail.fr/offres/reche...
# 9   https://candidat.francetravail.fr/offres/reche...
# 10  https://candidat.francetravail.fr/offres/reche...
# 11  https://candidat.francetravail.fr/offres/reche...
# 12  https://candidat.francetravail.fr/offres/reche...
# 13  https://candidat.francetravail.fr/offres/reche...
# 14  https://candidat.francetravail.fr/offres/reche...
# 15  https://candidat.francetravail.fr/offres/reche...
# 16  https://candidat.francetravail.fr/offres/reche...
# 17  https://candidat.francetravail.fr/offres/reche...
# 18  https://candidat.francetravail.fr/offres/reche...
# 19  https://candidat.francetravail.fr/offres/reche...
#
# [20 rows x 84 columns]
# 50 offres uniques exportées dans offres_emploi.csv ✅

# %%
print i
# Out:
#   Cell In [111], line 1
#     print i
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# # ---------------------------
# # CONFIGURATION
# # ---------------------------
# # France Travail (ex-Pôle emploi)
# # FT_CLIENT_ID = Defined in .env
# # FT_CLIENT_SECRET = Defined in .env
# # FT_SCOPE = Defined in .env

# ##################  VARIABLES  ##################
# FT_CLIENT_ID = os.environ.get("FT_CLIENT_ID")
# FT_CLIENT_SECRET = os.environ.get("FT_CLIENT_SECRET")
# FT_SCOPE = os.environ.get("FT_SCOPE")

# # Paramètres de recherche
# JOB_QUERY = "data scientist"
# COMMUNE = "78300"
# DISTANCE = 500
# BLOC_PAGINATION = 50

# MAX_PAGES = 10   # Limiter le nombre de pages récupérées

# # ---------------------------
# # AUTH FRANCE TRAVAIL
# # ---------------------------
# def get_ft_token():
#     url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
#     data = {
#         "grant_type": "client_credentials",
#         "client_id": FT_CLIENT_ID,
#         "client_secret": FT_CLIENT_SECRET,
#         "scope": FT_SCOPE,
#     }
#     r = requests.post(url, data=data)
#     r.raise_for_status()
#     return r.json()["access_token"]

# # ---------------------------
# # API CALL FRANCE TRAVAIL
# # ---------------------------
# def fetch_france_travail_jobs(token, max_pages=MAX_PAGES):
#     headers = {"Authorization": f"Bearer {token}"}
#     all_jobs = []
#     b_stop_criteria = False
#     b_first_pass = True
    
#     for page in range(1, max_pages + 1):
#         if b_stop_criteria == False:    
#             url = f"https://api.francetravail.io/partenaire/offresdemploi/v2/offres/search"
#             params = {
#                 "motsCles": JOB_QUERY,
#                 "commune": COMMUNE,
#                 "distance" : DISTANCE,
#                 "range": f"{(page-1)*BLOC_PAGINATION}-{page*BLOC_PAGINATION-1}"  # pagination par blocs de 50
#             }
#             r = requests.get(url, headers=headers, params=params)
#             r.raise_for_status()
#             data = r.json()
#             offres = data.get("resultats", [])

#             if b_first_pass == True:
#                 # Transformer en DataFrame en aplatissant les colonnes imbriquées
#                 df = pd.json_normalize(offres,sep="_")  # pour que les clés imbriquées deviennent "lieuTravail.libelle", etc.
#             else:
#                 df = pd.concat([df,pd.json_normalize(offres,sep="_")])

            
#             print(len(offres))
            
#             if len(offres) < BLOC_PAGINATION:
#                 b_stop_criteria = True

#             b_first_pass = False
            
#     return df

# # ---------------------------
# # MAIN
# # ---------------------------
# if __name__ == "__main__":
#     print("Authentification France Travail...")
#     token = get_ft_token()

#     print("Récupération des offres France Travail...")
#     ft_jobs_df = fetch_france_travail_jobs(token)

#     # print("Affichage Extract offres France Travail...")
#     # df = pd.DataFrame(ft_jobs)
#     # display(df.tail(5))

#     # Export vers CSV
#     ft_jobs_df.to_csv("../data/raw_data/offres_emploi.csv", index=False, encoding="utf-8")
#     print(f"{len(ft_jobs_df)} offres uniques exportées dans offres_emploi.csv ✅")
# Out:
# Authentification France Travail...
# Récupération des offres France Travail...
# 50
# 50
# 1
# 101 offres uniques exportées dans offres_emploi.csv ✅

# %%
# # ---------------------------
# # CONFIGURATION
# # ---------------------------
# # France Travail (ex-Pôle emploi)
# # FT_CLIENT_ID = Defined in .env
# # FT_CLIENT_SECRET = Defined in .env
# # FT_SCOPE = Defined in .env

# ##################  VARIABLES  ##################
# FT_CLIENT_ID = os.environ.get("FT_CLIENT_ID")
# FT_CLIENT_SECRET = os.environ.get("FT_CLIENT_SECRET")
# FT_SCOPE = os.environ.get("FT_SCOPE")

# # Paramètres de recherche
# JOB_QUERY = "data scientist"
# COMMUNE = "78300"
# DISTANCE = 500
# BLOC_PAGINATION = 50

# MAX_PAGES = 1   # Limiter le nombre de pages récupérées

# # ---------------------------
# # AUTH FRANCE TRAVAIL
# # ---------------------------
# def get_ft_token():
#     url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
#     data = {
#         "grant_type": "client_credentials",
#         "client_id": FT_CLIENT_ID,
#         "client_secret": FT_CLIENT_SECRET,
#         "scope": FT_SCOPE,
#     }
#     r = requests.post(url, data=data)
#     r.raise_for_status()
#     return r.json()["access_token"]

# # ---------------------------
# # API CALL FRANCE TRAVAIL
# # ---------------------------
# def fetch_france_travail_jobs(token, max_pages=MAX_PAGES):
#     headers = {"Authorization": f"Bearer {token}"}
#     all_jobs = []
#     b_stop_criteria = False
    
#     for page in range(1, max_pages + 1):
#         if b_stop_criteria == False:    
#             url = f"https://api.francetravail.io/partenaire/offresdemploi/v2/offres/search"
#             params = {
#                 "motsCles": JOB_QUERY,
#                 "commune": COMMUNE,
#                 "distance" : DISTANCE,
#                 "range": f"{(page-1)*BLOC_PAGINATION}-{page*BLOC_PAGINATION-1}"  # pagination par blocs de 50
#             }
#             r = requests.get(url, headers=headers, params=params)
#             r.raise_for_status()
#             data = r.json()
#             offres = data.get("resultats", [])
                
#             for o in offres:
#                 all_jobs.append({
#                     "source": "France Travail",
#                     "id":o.get("id"),                    
#                     "titre": o.get("intitule"),
#                     "description": o.get("description"),
#                     "date": o.get("dateCreation"),
#                     "date_actualisation": o.get("dateActualisation"),
#                     "lieu_libelle": o.get("lieuTravail", {}).get("libelle"),
#                     "lieu_latitude": o.get("lieuTravail", {}).get("latitude"),
#                     "lieu_longitude": o.get("lieuTravail", {}).get("longitude"),
#                     "lieu_codePostal": o.get("lieuTravail", {}).get("codePostal"),
#                     "lieu_commune": o.get("lieuTravail", {}).get("commune"),
#                     "entreprise_nom": o.get("entreprise", {}).get("nom"),
#                     "entreprise_description": o.get("entreprise", {}).get("description"),
#                     "entreprise_logo": o.get("entreprise", {}).get("logo"),
#                     "entreprise_url": o.get("entreprise", {}).get("url"),
#                     "typeContrat": o.get("typeContrat"),
#                     "typeContratLibelle": o.get("typeContratLibelle"),
#                     "natureContrat": o.get("natureContrat"),
#                     "experienceExige": o.get("experienceExige"),
#                     "experienceLibelle": o.get("experienceLibelle"),
#                     "experienceCommentaire": o.get("experienceCommentaire"),
#                     "experienceCommentaire": o.get("experienceCommentaire"),      

#                     "formations": o.get("formations"),
#                     # if len(o.get("formations")) != 0:
#                     #     "codeFormation": o.get("formations",{}).get("codeFormation"),   
                
#                     # if isinstance(o.get("formations"), list):
#                     #     "codeFormation": o.get("formations"),
#                     # "codeFormation": o.get("formations", []).get("codeFormation"),

                    
#                     "lieu": o.get("lieuTravail", {}).get("libelle"),                    
#                     "url": o.get("origineOffre", {}).get("urlOrigine")
#                 })
#             print(len(offres))
            
#             if len(offres) < BLOC_PAGINATION:
#                 b_stop_criteria = True
            
#     return all_jobs

# # ---------------------------
# # MAIN
# # ---------------------------
# if __name__ == "__main__":
#     print("Authentification France Travail...")
#     token = get_ft_token()

#     print("Récupération des offres France Travail...")
#     ft_jobs = fetch_france_travail_jobs(token)

#     print("Affichage Extract offres France Travail...")
#     df = pd.DataFrame(ft_jobs)
#     display(df.tail(5))

#     # Export vers CSV
#     df.to_csv("../data/raw_data/offres_emploi.csv", index=False, encoding="utf-8")
#     print(f"{len(ft_jobs)} offres uniques exportées dans offres_emploi.csv ✅")
# Out:
# Authentification France Travail...
# Récupération des offres France Travail...
# 50
# Affichage Extract offres France Travail...
#             source       id  \
# 45  France Travail  1230514
# 46  France Travail  1213064
# 47  France Travail  1041235
# 48  France Travail  0547772
# 49  France Travail  0393053
#
#                                                 titre  \
# 45                               Data scientist (H/F)
# 46  DATA SCIENTIST SENIOR F/H - Système, réseaux, ...
# 47  Banque de France - Data Scientist expérimenté ...
# 48                               Data scientist (H/F)
# 49                Datascientist confirme(e) F/H (H/F)
#
#                                           description  \
# 45  Description du poste :\nEn rejoignant cette en...
# 46  Descriptif du poste:\n\nNous recherchons un(e)...
# 47  DESCRIPTIF DE MISSION\n\nLe pôle « Statistique...
# 48  Description du poste :\nEnvie de piloter des p...
# 49  La Fabrique du Pôle Numérique et Data de la Di...
#
#                         date        date_actualisation   lieu_libelle  \
# 45  2025-08-21T11:36:40.000Z  2025-08-21T11:36:40.000Z  75 - PARIS 09
# 46  2025-08-20T17:30:21.000Z  2025-08-21T06:33:21.000Z  92 - NANTERRE
# 47  2025-08-15T03:58:47.000Z  2025-08-15T03:58:47.000Z  75 - PARIS 02
# 48  2025-08-02T08:53:36.000Z  2025-09-06T08:04:05.000Z  75 - PARIS 09
# 49  2025-07-30T10:38:24.000Z  2025-08-08T05:34:39.000Z   92 - PUTEAUX
#
#     lieu_latitude  lieu_longitude lieu_codePostal  ... entreprise_url  \
# 45      48.872479        2.341194           75009  ...           None
# 46      48.897181        2.222257           92000  ...           None
# 47            NaN             NaN           75002  ...           None
# 48      48.872479        2.341194           75009  ...           None
# 49      48.884019        2.237979           92800  ...           None
#
#    typeContrat                   typeContratLibelle    natureContrat  \
# 45         CDI         Contrat à durée indéterminée  Contrat travail
# 46         CDI         Contrat à durée indéterminée  Contrat travail
# 47         CDD  Contrat à durée déterminée - 9 Mois  Contrat travail
# 48         CDI         Contrat à durée indéterminée  Contrat travail
# 49         CDI         Contrat à durée indéterminée  Contrat travail
#
#    experienceExige             experienceLibelle experienceCommentaire  \
# 45               E  Expérience exigée de 1 An(s)                  None
# 46               E  Expérience exigée de 5 An(s)                  None
# 47               E             Expérience exigée                  None
# 48               E  Expérience exigée de 1 An(s)                  None
# 49               D              Débutant accepté                  None
#
#    formations           lieu  \
# 45       None  75 - PARIS 09
# 46       None  92 - NANTERRE
# 47       None  75 - PARIS 02
# 48       None  75 - PARIS 09
# 49       None   92 - PUTEAUX
#
#                                                   url
# 45  https://candidat.francetravail.fr/offres/reche...
# 46  https://candidat.francetravail.fr/offres/reche...
# 47  https://candidat.francetravail.fr/offres/reche...
# 48  https://candidat.francetravail.fr/offres/reche...
# 49  https://candidat.francetravail.fr/offres/reche...
#
# [5 rows x 24 columns]
# 50 offres uniques exportées dans offres_emploi.csv ✅

# %%
# # ---------------------------
# # CONFIGURATION
# # ---------------------------
# # France Travail (ex-Pôle emploi)
# # FT_CLIENT_ID = Defined in .env
# # FT_CLIENT_SECRET = Defined in .env
# # FT_SCOPE = Defined in .env

# ##################  VARIABLES  ##################
# FT_CLIENT_ID = os.environ.get("FT_CLIENT_ID")
# FT_CLIENT_SECRET = os.environ.get("FT_CLIENT_SECRET")
# FT_SCOPE = os.environ.get("FT_SCOPE")

# # Paramètres de recherche
# JOB_QUERY = "data engineer"
# COMMUNE = "78300"
# DISTANCE = 500
# BLOC_PAGINATION = 50

# MAX_PAGES = 20   # Limiter le nombre de pages récupérées

# # ---------------------------
# # AUTH FRANCE TRAVAIL
# # ---------------------------
# def get_ft_token():
#     url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
#     data = {
#         "grant_type": "client_credentials",
#         "client_id": FT_CLIENT_ID,
#         "client_secret": FT_CLIENT_SECRET,
#         "scope": FT_SCOPE,
#     }
#     r = requests.post(url, data=data)
#     r.raise_for_status()
#     return r.json()["access_token"]

# # ---------------------------
# # API CALL FRANCE TRAVAIL
# # ---------------------------
# def fetch_france_travail_jobs(token, max_pages=MAX_PAGES):
#     headers = {"Authorization": f"Bearer {token}"}
#     all_jobs = []
#     b_stop_criteria = False
    
#     for page in range(1, max_pages + 1):
#         if b_stop_criteria == False:    
#             url = f"https://api.francetravail.io/partenaire/offresdemploi/v2/offres/search"
#             params = {
#                 "motsCles": JOB_QUERY,
#                 "commune": COMMUNE,
#                 "distance" : DISTANCE,
#                 "range": f"{(page-1)*BLOC_PAGINATION}-{page*BLOC_PAGINATION-1}"  # pagination par blocs de 50
#             }
#             r = requests.get(url, headers=headers, params=params)
#             r.raise_for_status()
#             data = r.json()
#             offres = data.get("resultats", [])
#             for o in offres:
#                 all_jobs.append({
#                     "source": "France Travail",
#                     "titre": o.get("intitule"),
#                     "entreprise": o.get("entreprise", {}).get("nom"),
#                     "lieu": o.get("lieuTravail", {}).get("libelle"),
#                     "date": o.get("dateCreation"),
#                     "url": o.get("origineOffre", {}).get("urlOrigine"),
#                 })
#             print(len(offres))
            
#             if len(offres) < BLOC_PAGINATION:
#                 b_stop_criteria = True
            
#     return all_jobs

# # ---------------------------
# # MAIN
# # ---------------------------
# if __name__ == "__main__":
#     print("Authentification France Travail...")
#     token = get_ft_token()

#     print("Récupération des offres France Travail...")
#     ft_jobs = fetch_france_travail_jobs(token)

#     print("Affichage Extract offres France Travail...")
#     df = pd.DataFrame(ft_jobs)
#     display(df.head(10))

#     # Export vers CSV
#     df.to_csv("../data/raw_data/offres_emploi.csv", index=False, encoding="utf-8")
#     print(f"{len(ft_jobs)} offres uniques exportées dans offres_emploi.csv ✅")
# Out:
# Authentification France Travail...
# Récupération des offres France Travail...
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 16
# Affichage Extract offres France Travail...
#            source                                 titre     entreprise  \
# 0  France Travail       Data Engineer - H/F - CDI (H/F)        POLYCEA
# 1  France Travail                         Data engineer         E-KENT
# 2  France Travail                         Data engineer          EPSYL
# 3  France Travail  Data Engineer Kafka / BigQuery (H/F)  SEGMENT ELITE
# 4  France Travail            Data Engineer - EMEA (H/F)         DOLEAD
# 5  France Travail               Data Engineer SQL (H/F)  SEGMENT ELITE
# 6  France Travail                   Data Engineer (H/F)  SEGMENT ELITE
# 7  France Travail                   Data engineer (H/F)       AMILTONE
# 8  France Travail     Software Engineer Data & AI (H/F)          HIPAY
# 9  France Travail                   Data engineer (H/F)           None
#
#                             lieu                      date  \
# 0                  75 - PARIS 09  2025-09-12T15:46:22.604Z
# 1  75 - Paris 13e Arrondissement  2025-09-12T16:20:49.815Z
# 2                  33 - Bordeaux  2025-09-12T16:01:21.737Z
# 3                  75 - PARIS 09  2025-09-11T18:06:20.094Z
# 4                  75 - PARIS 02  2025-09-11T09:48:37.782Z
# 5                  75 - PARIS 09  2025-09-09T13:23:39.343Z
# 6                  75 - PARIS 09  2025-09-09T13:13:35.180Z
# 7         59 - VILLENEUVE D ASCQ  2025-09-09T10:21:15.382Z
# 8                    44 - Nantes  2025-09-09T11:28:00.390Z
# 9                   69 - LYON 07  2025-09-08T11:38:56.778Z
#
#                                                  url
# 0  https://candidat.francetravail.fr/offres/reche...
# 1  https://candidat.francetravail.fr/offres/reche...
# 2  https://candidat.francetravail.fr/offres/reche...
# 3  https://candidat.francetravail.fr/offres/reche...
# 4  https://candidat.francetravail.fr/offres/reche...
# 5  https://candidat.francetravail.fr/offres/reche...
# 6  https://candidat.francetravail.fr/offres/reche...
# 7  https://candidat.francetravail.fr/offres/reche...
# 8  https://candidat.francetravail.fr/offres/reche...
# 9  https://candidat.francetravail.fr/offres/reche...
# 416 offres uniques exportées dans offres_emploi.csv ✅
