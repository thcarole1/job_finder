# %% [markdown]
# # Verification rapide des extractions

# %%
import http.client
import requests
import json
import pandas as pd
import os
pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_columns')

# %%
path = "../data/raw_data/"
file_name_FT = "offres_emploi_france_travail.csv"
file_name_adzuna = "offres_emploi_adzuna.csv"

# %%
df_FT = pd.read_csv(path+file_name_FT)
df_adzuna = pd.read_csv(path+file_name_adzuna)

# %%
print(df_FT.shape)
print(df_adzuna.shape)
# Out:
# (183, 76)
# (570, 76)

# %%
display(df_FT.head(20))
display(df_adzuna.head(20))
# Out:
#             source       id  \
# 0   France Travail  197PLRS
# 1   France Travail  197JSYL
# 2   France Travail  197FWLH
# 3   France Travail  197GFLX
# 4   France Travail  197DQJQ
# 5   France Travail  197FFNK
# 6   France Travail  197DCLX
# 7   France Travail  197BZSD
# 8   France Travail  196YKDB
# 9   France Travail  196RVBD
# 10  France Travail  195WMKG
# 11  France Travail  195TCNQ
# 12  France Travail  195BQWV
# 13  France Travail  197SRMC
# 14  France Travail  197QTVT
# 15  France Travail  197MRJZ
# 16  France Travail  196QYZV
# 17  France Travail  197FXJV
# 18  France Travail  197KWKK
# 19  France Travail  197BHJC
#
#                                                 titre  \
# 0                                  Data Analyst (h/f)
# 1                            Data analyst (F/H) (H/F)
# 2                           Data analyst senior (H/F)
# 3                                  Data analyst (F/H)
# 4                                  Data Analyst (H/F)
# ...
